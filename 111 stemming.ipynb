# %%
from nltk.stem import PorterStemmer

# %%
pip install nltk
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
connect_list=['connect','connected','connecting','connects','connectivity']
# create stemmer
ps = PorterStemmer()

# %%
for t in connect_list:
    print(t, " : ", ps.stem(t))
# Out:
# connect  :  connect
# connected  :  connect
# connecting  :  connect
# connects  :  connect
# connectivity  :  connect

# %%
test_list=['tested','testing','tests','testers']

# %%
for t in test_list:
    print(t," : ",ps.stem(t))
# Out:
# tested  :  test
# testing  :  test
# tests  :  test
# testers  :  tester

# %%
learn_list=['learns','Learning','learned','learners']

# %%
for t in learn_list:
    print(t," : ",ps.stem(t))
# Out:
# learns  :  learn
# Learning  :  learn
# learned  :  learn
# learners  :  learner

# %%
work_list=['works','working','worked','workers']

# %%
for t in work_list:
    print(t," : ",ps.stem(t))
# Out:
# works  :  work
# working  :  work
# worked  :  work
# workers  :  worker
